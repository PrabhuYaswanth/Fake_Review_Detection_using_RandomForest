# %% [markdown]
# ## Fake Review Detection

# %%
import pandas as pd

# %%
df=pd.read_csv("FakeReview.csv")
df.head()
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5     5.0    CG
# 1  Home_and_Kitchen_5     5.0    CG
# 2  Home_and_Kitchen_5     5.0    CG
# 3  Home_and_Kitchen_5     1.0    CG
# 4  Home_and_Kitchen_5     5.0    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40432 entries, 0 to 40431
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  40432 non-null  object
#  1   rating    40432 non-null  float64
#  2   label     40432 non-null  object
#  3   text_     40432 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (40432, 4)

# %%
df.isnull().sum() #Indicates No null Value
# Out:
# category    0
# rating      0
# label       0
# text_       0
# dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 5.0    24559
# 4.0     7965
# 3.0     3786
# 1.0     2155
# 2.0     1967
# Name: count, dtype: int64

# %%
print(df['label'].value_counts())
# Out:
# label
# CG    20216
# OR    20216
# Name: count, dtype: int64

# %%
df[df.duplicated()]# Contains Duplicate Values Drop the Duplicates
# Out:
#                            category  rating label  \
# 6025          Sports_and_Outdoors_5     5.0    CG
# 6708          Sports_and_Outdoors_5     5.0    CG
# 12548               Movies_and_TV_5     5.0    CG
# 19802                Pet_Supplies_5     5.0    CG
# 20242                Pet_Supplies_5     5.0    CG
# 22305                Pet_Supplies_5     5.0    OR
# 26444                Kindle_Store_5     5.0    CG
# 27233                Kindle_Store_5     5.0    CG
# 29203                       Books_5     5.0    CG
# 33602              Toys_and_Games_5     5.0    CG
# 34795              Toys_and_Games_5     5.0    CG
# 37543  Clothing_Shoes_and_Jewelry_5     5.0    CG
#
#                                                    text_
# 6025   This is a really good starter kit, with lots o...
# 6708   Great, no complaints. Comfortable, phone fits ...
# 12548  One of the best movies of the year.  Not for e...
# 19802  My dog loves these and it has kept her occupie...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (40420, 4)

# %%
print(df.duplicated().sum()) # Duplicates are Removed
# Out:
# 0

# %%
df['label'].value_counts() #Indicates This balanced Dataset
# Out:
# label
# OR    20215
# CG    20205
# Name: count, dtype: int64

# %% [markdown]
# #### Encode the Labels

# %%
df['label']=df['label'].map({'CG':0,'OR':1}) # CG -> computer Generated,
#OR original Review
df.head()
# Out:
#              category  rating  label  \
# 0  Home_and_Kitchen_5     5.0      0
# 1  Home_and_Kitchen_5     5.0      0
# 2  Home_and_Kitchen_5     5.0      0
# 3  Home_and_Kitchen_5     1.0      0
# 4  Home_and_Kitchen_5     5.0      0
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %% [markdown]
# #### Text Cleaning

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z ]', '', text)
    return text

# %%
df['text_'] = df['text_'].apply(clean_text)

# %%
df.head()
# Out:
#              category  rating  label  \
# 0  Home_and_Kitchen_5     5.0      0
# 1  Home_and_Kitchen_5     5.0      0
# 2  Home_and_Kitchen_5     5.0      0
# 3  Home_and_Kitchen_5     1.0      0
# 4  Home_and_Kitchen_5     5.0      0
#
#                                                text_
# 0  love this  well made sturdy and very comfortab...
# 1  love it a great upgrade from the original  ive...
# 2  this pillow saved my back i love the look and ...
# 3  missing information on how to use it but it is...
# 4  very nice set good quality we have had the set...

# %%
X=df['text_']
y=df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Convert the text To number using TF IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(stop_words='english')
X_train_vector=vectorizer.fit_transform(X_train)
X_test_vector=vectorizer.transform(X_test)

# %% [markdown]
# #### HyperParameter Tuning

# %% [markdown]
# #### Train the model

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(criterion='gini',random_state=42)
model.fit(X_train_vector,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# <h5>Grid SearchCV</h5>

# %%
from sklearn.model_selection import GridSearchCV

# %%
best_param=GridSearchCV(RandomForestClassifier(),
                       {
                           'n_estimators':[100,200],
                           'max_depth':[10,20]
                           
                       }, cv=5,scoring='accuracy'
                       )

# %%
best_param.fit(X_train_vector,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20], 'n_estimators': [100, 200]},
#              scoring='accuracy')

# %%
best_param.best_params_
# Out:
# {'max_depth': 20, 'n_estimators': 200}

# %%
best_param.best_score_
# Out:
# np.float64(0.8032090450363543)

# %%
#best_model=best_param.best_estimator_

# %% [markdown]
# <h5>takes Best model in best_parameter among
# Best parameters
# Best score
# Best model </h5>

# %%
y_pred =model.predict(X_test_vector)

# %%
model.score(X_train_vector,y_train)
# Out:
# 1.0

# %% [markdown]
# #### Evaluation Matrix

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      6094
#            1       0.88      0.79      0.83      6032
#
#     accuracy                           0.84     12126
#    macro avg       0.85      0.84      0.84     12126
# weighted avg       0.85      0.84      0.84     12126

# %%
import pickle

# %%
# save the model
with open("RFModel.pkl","wb") as file:
    pickle.dump(best_model,file)

# %%
# Save vectorizer
with open("vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
